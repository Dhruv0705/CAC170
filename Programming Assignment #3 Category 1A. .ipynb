# %%
#Dhruv Patel
#11/6/2021
#Programming Assignment #3 Category 1A

#Ask user to enter a note
#Defined Note
note=input("Please Enter A Musical Note")\
#if statemnet for each note with frequency
if note == "C4":
    print("Note Frequency is 261.63Hz ")
if note == "D4":
    print("Note Frequency is 293.66Hz")
if note == "E4":
    print ("Note Frequency is 329.63Hz")
if note == "G4":
    print("Note Frequency is 392.00Hz")
if note == "A4":
    print ("Note Frequency is 440.00Hz")
if note == "B4":
    print ("Note Frequency is 493.88Hz")
else:
    print ("Unkown Note, Please re-enter Note")
#errors: Unkown reason why it prints else statement when given the right note.
# Out:
# Please Enter A Musical NoteA4
# Note Frequency is 440.00Hz
# Unkown Note, Please re-enter Note
