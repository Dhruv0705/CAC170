# %%
#Dhruv Patel
#11/06/2021
#Dr. Win
#Programming Assignment #3 Category B #2
# Goal: Encrypt the message using a Caesar cipher that shifts all of the letters determined by the user
#NOTE: Did recive help with if statement and position from online from python statements and examples
#
# Read the text and shift from the user
#Define message and shift
text = input ("Enter the message:")
shift  = int (input ("Enter the shift value:"))
new_order  = ""
#Decrypt the given message from the user using x as an letter to define in the string in the user message 
for   x   in  text:
    if   x  >=   "a"   and   x  <=   "z":
        # Process a lowercase letter by determining its position in the alphabet (0 - 25),
        
        pos = ord (x) - ord ("a")
        pos = (pos + shift)  %  26
        new_char = chr (pos + ord ("a"))
        new_order = new_order+ new_char
    elif x >= "A"   and   x <=  "Z":
        # Process an uppercase letter by determining its position in the alphabet (0 - 25),
         
        
        pos = ord (x) -  ord ("A")
        pos = (pos +  shift)  %  26
        new_char = x(pos +  ord ("A"))
        new_message  = new_message +  new_char
    else :
        #If the character is Non-Letter, the message copies into a new message.
        new_order = new_order + x

# Display the encrypted message
print ("The Caesar Cipher message is: ", new_order)
# Out:
# Enter the message:abc
# Enter the shift value:1
# The Caesar Cipher message is:  bcd
