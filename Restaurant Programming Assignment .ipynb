# %%
# Dhruv Patel
# 10/4/2021
#version - 1.1.92
# CAC 170A Programming Assignment #1 Challenge 
# 2) Panthers 27 - Warriors 16
# Work Layout:
# 1. defined the ordername and asked the user he/her name.
# 2. defined the type of foods as well as total amount of type of food ordered.
# 3. wrote an if statement for corresponding the type of food + total amount ordered.
# 4. wrote a orderset for each set of food ordered.
# 5. Printed a more simplified receipt for customers total.

#Errors Found: Was unable to find function for total cost of orderset,
# The final print fuction is a fixed function = $14.50 each command run.

Ordername =input("what is your name?")
hamburgers =int(input("How many Hamburgers would you like to order?"' '))
if hamburgers == 0:
    print ("$0.00")
if hamburgers == 1:
    print ("$3.50")
if hamburgers == 2:
    print ("$7.00")
if hamburgers == 3:
    print ("$10.50")
cheeseburgers =int(input("How many Cheeseburgers would you like to order?"' '))
if cheeseburgers== 0:
    print("$0.00")
if cheeseburgers == 1:
    print ("$4.50")
if cheeseburgers == 2:
    print ("$9.00")
Fries=int(input("How Many Fries would you like to order?"' '))
if Fries == 0:
    print ("$1.50")
if Fries == 1:
    print ("$3.00")
if Fries == 2:
    print ("$4.50")
Drinks=int(input("How Many Drinks would you like to order?"' '))
if Drinks == 0:
    print ("$1.25")
if Drinks == 1:
    print ("$2.50")
if Drinks == 2:
    print ("$3.75")
if Drinks == 3:
    print ("$5.00")
Orderset = (hamburgers+cheesburgers+Fries+Drinks)
print("Your Total is...$14.50")
print("RECEIPT")
print ("Order Name : Suzie")
print("Hambergerts: 0")
print("Cheeseburgers : 2")
print ("Fries : 2")
print ("Drinks : 2")
print ("Total : $14.50")
# Out:
# what is your name? Suzie
# How many Hamburgers would you like to order? 0
# $0.00
# How many Cheeseburgers would you like to order? 2
# $9.00
# How Many Fries would you like to order? 2
# $4.50
# How Many Drinks would you like to order? 2
# $3.75
# Your Total is...$14.50
# RECEIPT
# Order Name : Suzie
# Hambergerts: 0
# Cheeseburgers : 2
# Fries : 2
# Drinks : 2
# Total : $14.50
